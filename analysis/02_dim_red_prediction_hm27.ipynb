# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import multiprocessing
import pprint
import os

from IPython import get_ipython
import shap
import numpy as np
from matplotlib import pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.metrics import (ConfusionMatrixDisplay, PrecisionRecallDisplay,
                             RocCurveDisplay, classification_report)
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline

from utils import *

# %%
ip = get_ipython()
path = None
if "__vsc_ipynb_file__" in ip.user_ns:
    path = ip.user_ns["__vsc_ipynb_file__"]

currfile = os.path.splitext(os.path.basename(path))[0]
currfile
# Out:
# '02_dim_red_prediction_hm27'

# %%
X, y = get_tumor_normal_ml_data(hm_27=True)

# %%
X_filtered = X.loc[:, X.isna().mean() < 0.8]
print("Dropped {N} columns with all NaN values".format(N=X.shape[1] - X_filtered.shape[1]))
# Out:
# Dropped 0 columns with all NaN values

# %%
X_filtered
# Out:
# ENTITY_STABLE_ID  cg00000292  cg00003994  cg00005847  cg00007981  cg00008493  \
# TCGA-2A-A8VL-01     0.743283    0.072272    0.615289    0.024384    0.928817
# TCGA-2A-A8VO-01     0.630143    0.133472    0.566151    0.023196    0.938485
# TCGA-2A-A8VT-01     0.633692    0.268712    0.728255    0.024627    0.922617
# TCGA-2A-A8VV-01     0.643800    0.079160    0.826008    0.022784    0.916749
# TCGA-2A-A8VX-01     0.796107    0.255795    0.836811    0.025117    0.928310
# ...                      ...         ...         ...         ...         ...
# TCGA-E9-A1RD-11A    0.070000    0.130000    0.040000    0.060000    0.010000
# TCGA-BH-A1FR-11B    0.070000    0.160000    0.030000    0.070000    0.010000
# TCGA-E9-A1RC-11A    0.150000    0.140000    0.060000    0.120000    0.010000
# TCGA-BH-A1F8-11B    0.080000    0.130000    0.020000    0.090000    0.010000
# TCGA-BH-A0B3-11B    0.040000    0.080000    0.030000    0.060000    0.010000
#
# ENTITY_STABLE_ID  cg00008713  cg00009407  cg00011459  cg00012199  cg00012386  \
# TCGA-2A-A8VL-01     0.055353    0.031280    0.946620    0.032639    0.035285
# TCGA-2A-A8VO-01     0.052331    0.024999    0.939624    0.026985    0.038910
# TCGA-2A-A8VT-01     0.032642    0.024788    0.829843    0.031472    0.028074
# TCGA-2A-A8VV-01     0.062634    0.024674    0.932249    0.039377    0.041003
# TCGA-2A-A8VX-01     0.047323    0.034034    0.908861    0.040282    0.049794
# ...                      ...         ...         ...         ...         ...
# TCGA-E9-A1RD-11A    0.030000    0.040000    0.030000    0.010000    0.050000
# TCGA-BH-A1FR-11B    0.010000    0.050000    0.020000    0.010000    0.030000
# TCGA-E9-A1RC-11A    0.020000    0.080000    0.070000    0.020000    0.070000
# TCGA-BH-A1F8-11B    0.020000    0.090000    0.030000    0.010000    0.030000
# TCGA-BH-A0B3-11B    0.020000    0.060000    0.010000    0.010000    0.020000
#
# ENTITY_STABLE_ID  ...  cg27651218  cg27652350  cg27653134  cg27654142  \
# TCGA-2A-A8VL-01   ...    0.913216    0.243026    0.498315    0.040869
# TCGA-2A-A8VO-01   ...    0.941886    0.101337    0.499453    0.036238
# TCGA-2A-A8VT-01   ...    0.913852    0.261440    0.677838    0.055831
# TCGA-2A-A8VV-01   ...    0.946643    0.093389    0.571192    0.038841
# TCGA-2A-A8VX-01   ...    0.933783    0.107742    0.549409    0.050328
# ...               ...         ...         ...         ...         ...
# TCGA-E9-A1RD-11A  ...    0.360000         NaN    0.340000    0.460000
# TCGA-BH-A1FR-11B  ...    0.430000         NaN    0.320000    0.440000
# TCGA-E9-A1RC-11A  ...    0.330000         NaN    0.320000    0.400000
# TCGA-BH-A1F8-11B  ...    0.380000         NaN    0.370000    0.460000
# TCGA-BH-A0B3-11B  ...    0.340000         NaN    0.480000    0.340000
#
# ENTITY_STABLE_ID  cg27655905  cg27657283  cg27661264  cg27662379  cg27662877  \
# TCGA-2A-A8VL-01     0.029888    0.022910    0.142701    0.045062    0.036641
# TCGA-2A-A8VO-01     0.039788    0.036157    0.335054    0.036540    0.027097
# TCGA-2A-A8VT-01     0.026104    0.027175    0.163027    0.046415    0.031748
# TCGA-2A-A8VV-01     0.034923    0.028802    0.122760    0.056377    0.029467
# TCGA-2A-A8VX-01     0.043812    0.038704    0.112784    0.052000    0.037906
# ...                      ...         ...         ...         ...         ...
# TCGA-E9-A1RD-11A    0.340000    0.230000    0.320000    0.260000         NaN
# TCGA-BH-A1FR-11B    0.260000    0.290000    0.290000    0.310000         NaN
# TCGA-E9-A1RC-11A    0.320000    0.260000    0.350000    0.220000         NaN
# TCGA-BH-A1F8-11B    0.350000    0.370000    0.350000    0.250000         NaN
# TCGA-BH-A0B3-11B    0.450000    0.360000    0.290000    0.290000         NaN
#
# ENTITY_STABLE_ID  cg27665659
# TCGA-2A-A8VL-01     0.063258
# TCGA-2A-A8VO-01     0.036544
# TCGA-2A-A8VT-01     0.042414
# TCGA-2A-A8VV-01     0.034029
# TCGA-2A-A8VX-01     0.039406
# ...                      ...
# TCGA-E9-A1RD-11A         NaN
# TCGA-BH-A1FR-11B         NaN
# TCGA-E9-A1RC-11A         NaN
# TCGA-BH-A1F8-11B         NaN
# TCGA-BH-A0B3-11B         NaN
#
# [2772 rows x 22601 columns]

# %%
X_filtered.shape, y.shape
# Out:
# ((2772, 22601), (2772,))

# %%
X_train, X_test, y_train, y_test = stratified_train_test_split(X_filtered, y)

# %%
# num_cpus = multiprocessing.cpu_count() // 2
num_cpus = 10

# %%
# If file best_params.json exists, load it
try:
    with open(f"{currfile}.best_params.json", "r") as file:
        best_params = json.load(file)
    results = pd.read_csv(f"{currfile}.hyperparmeter_tuning_results.csv")

except FileNotFoundError:
    best_params = None
    param_grid = {
        "classifier__tol": np.logspace(-6, -3, 10),
        "classifier__l1_ratio": np.linspace(0, 1, 20),
        "classifier__C": np.arange(2, 26, 5),
        "classifier__max_iter": np.arange(75, 151, 5),
        "embedder__n_components": np.arange(500, 2000, 250),
        "embedder__n_neighbors": np.arange(2, 100, 5),
        "embedder__tol": np.logspace(-6, -3, 10),
        "embedder__max_iter": np.arange(75, 151, 5),
        "embedder__hessian_tol": np.logspace(-6, -3, 10),
    }

    pipeline = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="mean")),
            ("embedder", LocallyLinearEmbedding(random_state=RANDOM_STATE, n_jobs=num_cpus, neighbors_algorithm="kd_tree")),
            (
                "classifier",
                LogisticRegression(
                    random_state=RANDOM_STATE,
                    n_jobs=num_cpus,
                    penalty="elasticnet",
                    solver="saga",
                    class_weight="balanced",
                ),
            ),
        ]
    )

    grid_search = RandomizedSearchCV(
        estimator=pipeline,
        param_distributions=param_grid,
        cv=5,
        n_jobs=num_cpus,
        n_iter=20,
        random_state=RANDOM_STATE,
        scoring="precision",
    )

    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_

    results = pd.DataFrame(grid_search.cv_results_)

    param_details = pd.json_normalize(results["params"])
    results = pd.concat([results, param_details], axis=1)

    results.to_csv(f"{currfile}.hyperparmeter_tuning_results.csv")
    best_params_serializable = {
        k: int(v) if isinstance(v, np.integer) else v for k, v in best_params.items()
    }

    with open(f"{currfile}.best_params.json", "w") as file:
        json.dump(best_params_serializable, file)

# %%
results
# Out:
#     Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            0      61.533080      2.516872        11.326279        1.048156
# 1            1      51.948256      6.272416         5.389934        0.617349
# 2            2      33.801613      3.540360         5.260033        0.422683
# 3            3      56.373630      2.833574         9.694811        0.946559
# 4            4      52.656914      2.812289        12.625431        2.423826
# 5            5      56.420105      1.325841         8.990189        0.781140
# 6            6      49.761919      4.745086        12.374081        1.300163
# 7            7      34.898386      2.059976         7.203868        1.087727
# 8            8      36.030415      3.178181        10.095297        2.246486
# 9            9      63.662106      2.439257        11.132988        0.465234
# 10          10      60.193296      4.886041        12.655137        1.551836
# 11          11      44.864069      1.220950         8.000244        0.374742
# 12          12      38.396544      1.289048         8.963791        0.411749
# 13          13      53.121399      1.360737         9.898023        0.631944
# 14          14      47.483011      3.521299        10.224376        1.931817
# 15          15      62.202140      1.755743         9.519589        1.018904
# 16          16      57.572346      2.510629        10.791267        1.681850
# 17          17      64.466223      2.984143        11.168541        0.639952
# 18          18      56.500294      4.696361        11.702422        0.585874
# 19          19      44.377516      1.936440         5.873696        0.301301
#
#     param_embedder__tol  param_embedder__n_neighbors  \
# 0              0.000005                           72
# 1              0.000022                            7
# 2              0.000001                           12
# 3              0.000022                           62
# 4              0.000001                           77
# 5              0.000010                           57
# 6              0.000464                           87
# 7              0.000022                            7
# 8              0.000001                            7
# 9              0.000022                           77
# 10             0.000005                           87
# 11             0.000046                           57
# 12             0.000046                           47
# 13             0.000215                           82
# 14             0.000100                           52
# 15             0.001000                           72
# 16             0.000100                           37
# 17             0.000002                           72
# 18             0.001000                           82
# 19             0.000215                           42
#
#     param_embedder__n_components  param_embedder__max_iter  \
# 0                            750                        90
# 1                           1500                       125
# 2                            750                       125
# 3                           1750                        80
# 4                           1000                       135
# 5                           1250                        80
# 6                            500                       105
# 7                            750                        75
# 8                           1000                        80
# 9                           1500                        90
# 10                          1250                       100
# 11                          1000                        85
# 12                           750                       135
# 13                          1000                        85
# 14                          1250                        95
# 15                          1500                       125
# 16                          1750                        75
# 17                           750                       110
# 18                           750                        90
# 19                          1750                       115
#
#     param_embedder__hessian_tol  ...  rank_test_score  embedder__tol  \
# 0                      0.000010  ...               16       0.000005
# 1                      0.000010  ...               13       0.000022
# 2                      0.000215  ...                1       0.000001
# 3                      0.000010  ...               15       0.000022
# 4                      0.000001  ...               17       0.000001
# 5                      0.000002  ...               19       0.000010
# 6                      0.000046  ...                9       0.000464
# 7                      0.000022  ...                6       0.000022
# 8                      0.000010  ...                5       0.000001
# 9                      0.000005  ...                4       0.000022
# 10                     0.001000  ...                8       0.000005
# 11                     0.000215  ...               12       0.000046
# 12                     0.000464  ...               14       0.000046
# 13                     0.000010  ...                1       0.000215
# 14                     0.000002  ...                3       0.000100
# 15                     0.000022  ...               18       0.001000
# 16                     0.001000  ...               11       0.000100
# 17                     0.001000  ...               10       0.000002
# 18                     0.000022  ...                7       0.001000
# 19                     0.000010  ...               20       0.000215
#
#     embedder__n_neighbors  embedder__n_components embedder__max_iter  \
# 0                      72                     750                 90
# 1                       7                    1500                125
# 2                      12                     750                125
# 3                      62                    1750                 80
# 4                      77                    1000                135
# 5                      57                    1250                 80
# 6                      87                     500                105
# 7                       7                     750                 75
# 8                       7                    1000                 80
# 9                      77                    1500                 90
# 10                     87                    1250                100
# 11                     57                    1000                 85
# 12                     47                     750                135
# 13                     82                    1000                 85
# 14                     52                    1250                 95
# 15                     72                    1500                125
# 16                     37                    1750                 75
# 17                     72                     750                110
# 18                     82                     750                 90
# 19                     42                    1750                115
#
#     embedder__hessian_tol  classifier__tol  classifier__max_iter  \
# 0                0.000010         0.000464                   100
# 1                0.000010         0.000010                   125
# 2                0.000215         0.000002                   130
# 3                0.000010         0.000002                   110
# 4                0.000001         0.000001                   140
# 5                0.000002         0.000010                   100
# 6                0.000046         0.001000                   135
# 7                0.000022         0.000100                   150
# 8                0.000010         0.001000                    80
# 9                0.000005         0.000010                    90
# 10               0.001000         0.000022                   125
# 11               0.000215         0.000100                    75
# 12               0.000464         0.000046                   150
# 13               0.000010         0.001000                   150
# 14               0.000002         0.000001                    75
# 15               0.000022         0.000001                   145
# 16               0.001000         0.000002                   145
# 17               0.001000         0.001000                   125
# 18               0.000022         0.000215                    80
# 19               0.000010         0.000215                   105
#
#     classifier__l1_ratio  classifier__C
# 0               0.631579             12
# 1               0.263158              7
# 2               0.157895             22
# 3               0.157895             22
# 4               0.052632              7
# 5               0.105263             17
# 6               0.052632              7
# 7               0.684211              2
# 8               0.421053              2
# 9               0.210526             17
# 10              0.315789             12
# 11              0.210526             22
# 12              1.000000              2
# 13              0.947368             22
# 14              0.578947             22
# 15              0.105263              2
# 16              0.368421              2
# 17              0.473684              7
# 18              0.000000              2
# 19              0.263158              7
#
# [20 rows x 32 columns]

# %%
print("Best parameters:")
pprint.pprint(best_params)
# Out:
# Best parameters:
# {'classifier__C': 22,
#  'classifier__l1_ratio': 0.15789473684210525,
#  'classifier__max_iter': 130,
#  'classifier__tol': 2.1544346900318822e-06,
#  'embedder__hessian_tol': 0.00021544346900318823,
#  'embedder__max_iter': 125,
#  'embedder__n_components': 750,
#  'embedder__n_neighbors': 12,
#  'embedder__tol': 1e-06}

# %%
embedder_args = {k.split("__")[1]: v for k, v in best_params.items() if "embedder" in k}
classifier_args = {k.split("__")[1]: v for k, v in best_params.items() if "classifier" in k}

classification_pipeline = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="mean")),
        (
            "embedder",
            LocallyLinearEmbedding(random_state=RANDOM_STATE, n_jobs=num_cpus, neighbors_algorithm="kd_tree", **embedder_args),
        ),
        (
            "classifier",
            LogisticRegression(
                random_state=RANDOM_STATE,
                n_jobs=num_cpus,
                penalty="elasticnet",
                solver="saga",
                class_weight="balanced",
                **classifier_args,
            ),
        ),
    ]
)

classification_pipeline.fit(X_train, y_train)
# Out:
# /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/env/jt_methylation_project/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Pipeline(steps=[('imputer', SimpleImputer()),
#                 ('embedder',
#                  LocallyLinearEmbedding(hessian_tol=0.00021544346900318823,
#                                         max_iter=125, n_components=750,
#                                         n_jobs=10, n_neighbors=12,
#                                         neighbors_algorithm='kd_tree',
#                                         random_state=42)),
#                 ('classifier',
#                  LogisticRegression(C=22, class_weight='balanced',
#                                     l1_ratio=0.15789473684210525, max_iter=130,
#                                     n_jobs=10, penalty='elasticnet',
#                                     random_state=42, solver='saga',
#                                     tol=2.1544346900318822e-06))])

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ConfusionMatrixDisplay.from_estimator(
    classification_pipeline,
    X_test,
    y_test,
    ax=ax[0],
    display_labels=["Normal", "Tumor"],
)
ax[0].set_title("Confusion Matrix")

RocCurveDisplay.from_estimator(
    classification_pipeline,
    X_test,
    y_test,
    ax=ax[1],
)
ax[1].set_title("ROC Curve")

PrecisionRecallDisplay.from_estimator(
    classification_pipeline,
    X_test,
    y_test,
    ax=ax[2],
)
ax[2].set_title("Precision-Recall Curve")


plt.tight_layout()
plt.show()

# %%
report = classification_report(y_test, classification_pipeline.predict(X_test))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        38
#            1       1.00      1.00      1.00       517
#
#     accuracy                           1.00       555
#    macro avg       1.00      1.00      1.00       555
# weighted avg       1.00      1.00      1.00       555

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
feature_names = X_filtered.columns
len(feature_names)
# Out:
# 22601

# %%
def model_predict(data_asarray):
    data_asframe = pd.DataFrame(data_asarray, columns=feature_names)
    return classification_pipeline.predict(data_asframe)

# %%
transformed_feature_names = classification_pipeline[:-1].get_feature_names_out(
    feature_names
)
transformed_feature_names
# Out:
# array(['locallylinearembedding0', 'locallylinearembedding1',
#        'locallylinearembedding2', 'locallylinearembedding3',
#        'locallylinearembedding4', 'locallylinearembedding5',
#        'locallylinearembedding6', 'locallylinearembedding7',
#        'locallylinearembedding8', 'locallylinearembedding9',
#        'locallylinearembedding10', 'locallylinearembedding11',
#        'locallylinearembedding12', 'locallylinearembedding13',
#        'locallylinearembedding14', 'locallylinearembedding15',
#        'locallylinearembedding16', 'locallylinearembedding17',
#        'locallylinearembedding18', 'locallylinearembedding19',
#        'locallylinearembedding20', 'locallylinearembedding21',
#        'locallylinearembedding22', 'locallylinearembedding23',
#        'locallylinearembedding24', 'locallylinearembedding25',
#        'locallylinearembedding26', 'locallylinearembedding27',
#        'locallylinearembedding28', 'locallylinearembedding29',
#        'locallylinearembedding30', 'locallylinearembedding31',
#        'locallylinearembedding32', 'locallylinearembedding33',
#        'locallylinearembedding34', 'locallylinearembedding35',
#        'locallylinearembedding36', 'locallylinearembedding37',
#        'locallylinearembedding38', 'locallylinearembedding39',
#        'locallylinearembedding40', 'locallylinearembedding41',
#        'locallylinearembedding42', 'locallylinearembedding43',
#        'locallylinearembedding44', 'locallylinearembedding45',
#        'locallylinearembedding46', 'locallylinearembedding47',
#        'locallylinearembedding48', 'locallylinearembedding49',
#        'locallylinearembedding50', 'locallylinearembedding51',
#        'locallylinearembedding52', 'locallylinearembedding53',
#        'locallylinearembedding54', 'locallylinearembedding55',
#        'locallylinearembedding56', 'locallylinearembedding57',
#        'locallylinearembedding58', 'locallylinearembedding59',
#        'locallylinearembedding60', 'locallylinearembedding61',
#        'locallylinearembedding62', 'locallylinearembedding63',
#        'locallylinearembedding64', 'locallylinearembedding65',
#        'locallylinearembedding66', 'locallylinearembedding67',
#        'locallylinearembedding68', 'locallylinearembedding69',
#        'locallylinearembedding70', 'locallylinearembedding71',
#        'locallylinearembedding72', 'locallylinearembedding73',
#        'locallylinearembedding74', 'locallylinearembedding75',
#        'locallylinearembedding76', 'locallylinearembedding77',
#        'locallylinearembedding78', 'locallylinearembedding79',
#        'locallylinearembedding80', 'locallylinearembedding81',
#        'locallylinearembedding82', 'locallylinearembedding83',
#        'locallylinearembedding84', 'locallylinearembedding85',
#        'locallylinearembedding86', 'locallylinearembedding87',
#        'locallylinearembedding88', 'locallylinearembedding89',
#        'locallylinearembedding90', 'locallylinearembedding91',
#        'locallylinearembedding92', 'locallylinearembedding93',
#        'locallylinearembedding94', 'locallylinearembedding95',
#        'locallylinearembedding96', 'locallylinearembedding97',
#        'locallylinearembedding98', 'locallylinearembedding99',
#        'locallylinearembedding100', 'locallylinearembedding101',
#        'locallylinearembedding102', 'locallylinearembedding103',
#        'locallylinearembedding104', 'locallylinearembedding105',
#        'locallylinearembedding106', 'locallylinearembedding107',
#        'locallylinearembedding108', 'locallylinearembedding109',
#        'locallylinearembedding110', 'locallylinearembedding111',
#        'locallylinearembedding112', 'locallylinearembedding113',
#        'locallylinearembedding114', 'locallylinearembedding115',
#        'locallylinearembedding116', 'locallylinearembedding117',
#        'locallylinearembedding118', 'locallylinearembedding119',
#        'locallylinearembedding120', 'locallylinearembedding121',
#        'locallylinearembedding122', 'locallylinearembedding123',
#        'locallylinearembedding124', 'locallylinearembedding125',
#        'locallylinearembedding126', 'locallylinearembedding127',
#        'locallylinearembedding128', 'locallylinearembedding129',
#        'locallylinearembedding130', 'locallylinearembedding131',
#        'locallylinearembedding132', 'locallylinearembedding133',
#        'locallylinearembedding134', 'locallylinearembedding135',
#        'locallylinearembedding136', 'locallylinearembedding137',
#        'locallylinearembedding138', 'locallylinearembedding139',
#        'locallylinearembedding140', 'locallylinearembedding141',
#        'locallylinearembedding142', 'locallylinearembedding143',
#        'locallylinearembedding144', 'locallylinearembedding145',
#        'locallylinearembedding146', 'locallylinearembedding147',
#        'locallylinearembedding148', 'locallylinearembedding149',
#        'locallylinearembedding150', 'locallylinearembedding151',
#        'locallylinearembedding152', 'locallylinearembedding153',
#        'locallylinearembedding154', 'locallylinearembedding155',
#        'locallylinearembedding156', 'locallylinearembedding157',
#        'locallylinearembedding158', 'locallylinearembedding159',
#        'locallylinearembedding160', 'locallylinearembedding161',
#        'locallylinearembedding162', 'locallylinearembedding163',
#        'locallylinearembedding164', 'locallylinearembedding165',
#        'locallylinearembedding166', 'locallylinearembedding167',
#        'locallylinearembedding168', 'locallylinearembedding169',
#        'locallylinearembedding170', 'locallylinearembedding171',
#        'locallylinearembedding172', 'locallylinearembedding173',
#        'locallylinearembedding174', 'locallylinearembedding175',
#        'locallylinearembedding176', 'locallylinearembedding177',
#        'locallylinearembedding178', 'locallylinearembedding179',
#        'locallylinearembedding180', 'locallylinearembedding181',
#        'locallylinearembedding182', 'locallylinearembedding183',
#        'locallylinearembedding184', 'locallylinearembedding185',
#        'locallylinearembedding186', 'locallylinearembedding187',
#        'locallylinearembedding188', 'locallylinearembedding189',
#        'locallylinearembedding190', 'locallylinearembedding191',
#        'locallylinearembedding192', 'locallylinearembedding193',
#        'locallylinearembedding194', 'locallylinearembedding195',
#        'locallylinearembedding196', 'locallylinearembedding197',
#        'locallylinearembedding198', 'locallylinearembedding199',
#        'locallylinearembedding200', 'locallylinearembedding201',
#        'locallylinearembedding202', 'locallylinearembedding203',
#        'locallylinearembedding204', 'locallylinearembedding205',
#        'locallylinearembedding206', 'locallylinearembedding207',
#        'locallylinearembedding208', 'locallylinearembedding209',
#        'locallylinearembedding210', 'locallylinearembedding211',
#        'locallylinearembedding212', 'locallylinearembedding213',
#        'locallylinearembedding214', 'locallylinearembedding215',
#        'locallylinearembedding216', 'locallylinearembedding217',
#        'locallylinearembedding218', 'locallylinearembedding219',
#        'locallylinearembedding220', 'locallylinearembedding221',
#        'locallylinearembedding222', 'locallylinearembedding223',
#        'locallylinearembedding224', 'locallylinearembedding225',
#        'locallylinearembedding226', 'locallylinearembedding227',
#        'locallylinearembedding228', 'locallylinearembedding229',
#        'locallylinearembedding230', 'locallylinearembedding231',
#        'locallylinearembedding232', 'locallylinearembedding233',
#        'locallylinearembedding234', 'locallylinearembedding235',
#        'locallylinearembedding236', 'locallylinearembedding237',
#        'locallylinearembedding238', 'locallylinearembedding239',
#        'locallylinearembedding240', 'locallylinearembedding241',
#        'locallylinearembedding242', 'locallylinearembedding243',
#        'locallylinearembedding244', 'locallylinearembedding245',
#        'locallylinearembedding246', 'locallylinearembedding247',
#        'locallylinearembedding248', 'locallylinearembedding249',
#        'locallylinearembedding250', 'locallylinearembedding251',
#        'locallylinearembedding252', 'locallylinearembedding253',
#        'locallylinearembedding254', 'locallylinearembedding255',
#        'locallylinearembedding256', 'locallylinearembedding257',
#        'locallylinearembedding258', 'locallylinearembedding259',
#        'locallylinearembedding260', 'locallylinearembedding261',
#        'locallylinearembedding262', 'locallylinearembedding263',
#        'locallylinearembedding264', 'locallylinearembedding265',
#        'locallylinearembedding266', 'locallylinearembedding267',
#        'locallylinearembedding268', 'locallylinearembedding269',
#        'locallylinearembedding270', 'locallylinearembedding271',
#        'locallylinearembedding272', 'locallylinearembedding273',
#        'locallylinearembedding274', 'locallylinearembedding275',
#        'locallylinearembedding276', 'locallylinearembedding277',
#        'locallylinearembedding278', 'locallylinearembedding279',
#        'locallylinearembedding280', 'locallylinearembedding281',
#        'locallylinearembedding282', 'locallylinearembedding283',
#        'locallylinearembedding284', 'locallylinearembedding285',
#        'locallylinearembedding286', 'locallylinearembedding287',
#        'locallylinearembedding288', 'locallylinearembedding289',
#        'locallylinearembedding290', 'locallylinearembedding291',
#        'locallylinearembedding292', 'locallylinearembedding293',
#        'locallylinearembedding294', 'locallylinearembedding295',
#        'locallylinearembedding296', 'locallylinearembedding297',
#        'locallylinearembedding298', 'locallylinearembedding299',
#        'locallylinearembedding300', 'locallylinearembedding301',
#        'locallylinearembedding302', 'locallylinearembedding303',
#        'locallylinearembedding304', 'locallylinearembedding305',
#        'locallylinearembedding306', 'locallylinearembedding307',
#        'locallylinearembedding308', 'locallylinearembedding309',
#        'locallylinearembedding310', 'locallylinearembedding311',
#        'locallylinearembedding312', 'locallylinearembedding313',
#        'locallylinearembedding314', 'locallylinearembedding315',
#        'locallylinearembedding316', 'locallylinearembedding317',
#        'locallylinearembedding318', 'locallylinearembedding319',
#        'locallylinearembedding320', 'locallylinearembedding321',
#        'locallylinearembedding322', 'locallylinearembedding323',
#        'locallylinearembedding324', 'locallylinearembedding325',
#        'locallylinearembedding326', 'locallylinearembedding327',
#        'locallylinearembedding328', 'locallylinearembedding329',
#        'locallylinearembedding330', 'locallylinearembedding331',
#        'locallylinearembedding332', 'locallylinearembedding333',
#        'locallylinearembedding334', 'locallylinearembedding335',
#        'locallylinearembedding336', 'locallylinearembedding337',
#        'locallylinearembedding338', 'locallylinearembedding339',
#        'locallylinearembedding340', 'locallylinearembedding341',
#        'locallylinearembedding342', 'locallylinearembedding343',
#        'locallylinearembedding344', 'locallylinearembedding345',
#        'locallylinearembedding346', 'locallylinearembedding347',
#        'locallylinearembedding348', 'locallylinearembedding349',
#        'locallylinearembedding350', 'locallylinearembedding351',
#        'locallylinearembedding352', 'locallylinearembedding353',
#        'locallylinearembedding354', 'locallylinearembedding355',
#        'locallylinearembedding356', 'locallylinearembedding357',
#        'locallylinearembedding358', 'locallylinearembedding359',
#        'locallylinearembedding360', 'locallylinearembedding361',
#        'locallylinearembedding362', 'locallylinearembedding363',
#        'locallylinearembedding364', 'locallylinearembedding365',
#        'locallylinearembedding366', 'locallylinearembedding367',
#        'locallylinearembedding368', 'locallylinearembedding369',
#        'locallylinearembedding370', 'locallylinearembedding371',
#        'locallylinearembedding372', 'locallylinearembedding373',
#        'locallylinearembedding374', 'locallylinearembedding375',
#        'locallylinearembedding376', 'locallylinearembedding377',
#        'locallylinearembedding378', 'locallylinearembedding379',
#        'locallylinearembedding380', 'locallylinearembedding381',
#        'locallylinearembedding382', 'locallylinearembedding383',
#        'locallylinearembedding384', 'locallylinearembedding385',
#        'locallylinearembedding386', 'locallylinearembedding387',
#        'locallylinearembedding388', 'locallylinearembedding389',
#        'locallylinearembedding390', 'locallylinearembedding391',
#        'locallylinearembedding392', 'locallylinearembedding393',
#        'locallylinearembedding394', 'locallylinearembedding395',
#        'locallylinearembedding396', 'locallylinearembedding397',
#        'locallylinearembedding398', 'locallylinearembedding399',
#        'locallylinearembedding400', 'locallylinearembedding401',
#        'locallylinearembedding402', 'locallylinearembedding403',
#        'locallylinearembedding404', 'locallylinearembedding405',
#        'locallylinearembedding406', 'locallylinearembedding407',
#        'locallylinearembedding408', 'locallylinearembedding409',
#        'locallylinearembedding410', 'locallylinearembedding411',
#        'locallylinearembedding412', 'locallylinearembedding413',
#        'locallylinearembedding414', 'locallylinearembedding415',
#        'locallylinearembedding416', 'locallylinearembedding417',
#        'locallylinearembedding418', 'locallylinearembedding419',
#        'locallylinearembedding420', 'locallylinearembedding421',
#        'locallylinearembedding422', 'locallylinearembedding423',
#        'locallylinearembedding424', 'locallylinearembedding425',
#        'locallylinearembedding426', 'locallylinearembedding427',
#        'locallylinearembedding428', 'locallylinearembedding429',
#        'locallylinearembedding430', 'locallylinearembedding431',
#        'locallylinearembedding432', 'locallylinearembedding433',
#        'locallylinearembedding434', 'locallylinearembedding435',
#        'locallylinearembedding436', 'locallylinearembedding437',
#        'locallylinearembedding438', 'locallylinearembedding439',
#        'locallylinearembedding440', 'locallylinearembedding441',
#        'locallylinearembedding442', 'locallylinearembedding443',
#        'locallylinearembedding444', 'locallylinearembedding445',
#        'locallylinearembedding446', 'locallylinearembedding447',
#        'locallylinearembedding448', 'locallylinearembedding449',
#        'locallylinearembedding450', 'locallylinearembedding451',
#        'locallylinearembedding452', 'locallylinearembedding453',
#        'locallylinearembedding454', 'locallylinearembedding455',
#        'locallylinearembedding456', 'locallylinearembedding457',
#        'locallylinearembedding458', 'locallylinearembedding459',
#        'locallylinearembedding460', 'locallylinearembedding461',
#        'locallylinearembedding462', 'locallylinearembedding463',
#        'locallylinearembedding464', 'locallylinearembedding465',
#        'locallylinearembedding466', 'locallylinearembedding467',
#        'locallylinearembedding468', 'locallylinearembedding469',
#        'locallylinearembedding470', 'locallylinearembedding471',
#        'locallylinearembedding472', 'locallylinearembedding473',
#        'locallylinearembedding474', 'locallylinearembedding475',
#        'locallylinearembedding476', 'locallylinearembedding477',
#        'locallylinearembedding478', 'locallylinearembedding479',
#        'locallylinearembedding480', 'locallylinearembedding481',
#        'locallylinearembedding482', 'locallylinearembedding483',
#        'locallylinearembedding484', 'locallylinearembedding485',
#        'locallylinearembedding486', 'locallylinearembedding487',
#        'locallylinearembedding488', 'locallylinearembedding489',
#        'locallylinearembedding490', 'locallylinearembedding491',
#        'locallylinearembedding492', 'locallylinearembedding493',
#        'locallylinearembedding494', 'locallylinearembedding495',
#        'locallylinearembedding496', 'locallylinearembedding497',
#        'locallylinearembedding498', 'locallylinearembedding499',
#        'locallylinearembedding500', 'locallylinearembedding501',
#        'locallylinearembedding502', 'locallylinearembedding503',
#        'locallylinearembedding504', 'locallylinearembedding505',
#        'locallylinearembedding506', 'locallylinearembedding507',
#        'locallylinearembedding508', 'locallylinearembedding509',
#        'locallylinearembedding510', 'locallylinearembedding511',
#        'locallylinearembedding512', 'locallylinearembedding513',
#        'locallylinearembedding514', 'locallylinearembedding515',
#        'locallylinearembedding516', 'locallylinearembedding517',
#        'locallylinearembedding518', 'locallylinearembedding519',
#        'locallylinearembedding520', 'locallylinearembedding521',
#        'locallylinearembedding522', 'locallylinearembedding523',
#        'locallylinearembedding524', 'locallylinearembedding525',
#        'locallylinearembedding526', 'locallylinearembedding527',
#        'locallylinearembedding528', 'locallylinearembedding529',
#        'locallylinearembedding530', 'locallylinearembedding531',
#        'locallylinearembedding532', 'locallylinearembedding533',
#        'locallylinearembedding534', 'locallylinearembedding535',
#        'locallylinearembedding536', 'locallylinearembedding537',
#        'locallylinearembedding538', 'locallylinearembedding539',
#        'locallylinearembedding540', 'locallylinearembedding541',
#        'locallylinearembedding542', 'locallylinearembedding543',
#        'locallylinearembedding544', 'locallylinearembedding545',
#        'locallylinearembedding546', 'locallylinearembedding547',
#        'locallylinearembedding548', 'locallylinearembedding549',
#        'locallylinearembedding550', 'locallylinearembedding551',
#        'locallylinearembedding552', 'locallylinearembedding553',
#        'locallylinearembedding554', 'locallylinearembedding555',
#        'locallylinearembedding556', 'locallylinearembedding557',
#        'locallylinearembedding558', 'locallylinearembedding559',
#        'locallylinearembedding560', 'locallylinearembedding561',
#        'locallylinearembedding562', 'locallylinearembedding563',
#        'locallylinearembedding564', 'locallylinearembedding565',
#        'locallylinearembedding566', 'locallylinearembedding567',
#        'locallylinearembedding568', 'locallylinearembedding569',
#        'locallylinearembedding570', 'locallylinearembedding571',
#        'locallylinearembedding572', 'locallylinearembedding573',
#        'locallylinearembedding574', 'locallylinearembedding575',
#        'locallylinearembedding576', 'locallylinearembedding577',
#        'locallylinearembedding578', 'locallylinearembedding579',
#        'locallylinearembedding580', 'locallylinearembedding581',
#        'locallylinearembedding582', 'locallylinearembedding583',
#        'locallylinearembedding584', 'locallylinearembedding585',
#        'locallylinearembedding586', 'locallylinearembedding587',
#        'locallylinearembedding588', 'locallylinearembedding589',
#        'locallylinearembedding590', 'locallylinearembedding591',
#        'locallylinearembedding592', 'locallylinearembedding593',
#        'locallylinearembedding594', 'locallylinearembedding595',
#        'locallylinearembedding596', 'locallylinearembedding597',
#        'locallylinearembedding598', 'locallylinearembedding599',
#        'locallylinearembedding600', 'locallylinearembedding601',
#        'locallylinearembedding602', 'locallylinearembedding603',
#        'locallylinearembedding604', 'locallylinearembedding605',
#        'locallylinearembedding606', 'locallylinearembedding607',
#        'locallylinearembedding608', 'locallylinearembedding609',
#        'locallylinearembedding610', 'locallylinearembedding611',
#        'locallylinearembedding612', 'locallylinearembedding613',
#        'locallylinearembedding614', 'locallylinearembedding615',
#        'locallylinearembedding616', 'locallylinearembedding617',
#        'locallylinearembedding618', 'locallylinearembedding619',
#        'locallylinearembedding620', 'locallylinearembedding621',
#        'locallylinearembedding622', 'locallylinearembedding623',
#        'locallylinearembedding624', 'locallylinearembedding625',
#        'locallylinearembedding626', 'locallylinearembedding627',
#        'locallylinearembedding628', 'locallylinearembedding629',
#        'locallylinearembedding630', 'locallylinearembedding631',
#        'locallylinearembedding632', 'locallylinearembedding633',
#        'locallylinearembedding634', 'locallylinearembedding635',
#        'locallylinearembedding636', 'locallylinearembedding637',
#        'locallylinearembedding638', 'locallylinearembedding639',
#        'locallylinearembedding640', 'locallylinearembedding641',
#        'locallylinearembedding642', 'locallylinearembedding643',
#        'locallylinearembedding644', 'locallylinearembedding645',
#        'locallylinearembedding646', 'locallylinearembedding647',
#        'locallylinearembedding648', 'locallylinearembedding649',
#        'locallylinearembedding650', 'locallylinearembedding651',
#        'locallylinearembedding652', 'locallylinearembedding653',
#        'locallylinearembedding654', 'locallylinearembedding655',
#        'locallylinearembedding656', 'locallylinearembedding657',
#        'locallylinearembedding658', 'locallylinearembedding659',
#        'locallylinearembedding660', 'locallylinearembedding661',
#        'locallylinearembedding662', 'locallylinearembedding663',
#        'locallylinearembedding664', 'locallylinearembedding665',
#        'locallylinearembedding666', 'locallylinearembedding667',
#        'locallylinearembedding668', 'locallylinearembedding669',
#        'locallylinearembedding670', 'locallylinearembedding671',
#        'locallylinearembedding672', 'locallylinearembedding673',
#        'locallylinearembedding674', 'locallylinearembedding675',
#        'locallylinearembedding676', 'locallylinearembedding677',
#        'locallylinearembedding678', 'locallylinearembedding679',
#        'locallylinearembedding680', 'locallylinearembedding681',
#        'locallylinearembedding682', 'locallylinearembedding683',
#        'locallylinearembedding684', 'locallylinearembedding685',
#        'locallylinearembedding686', 'locallylinearembedding687',
#        'locallylinearembedding688', 'locallylinearembedding689',
#        'locallylinearembedding690', 'locallylinearembedding691',
#        'locallylinearembedding692', 'locallylinearembedding693',
#        'locallylinearembedding694', 'locallylinearembedding695',
#        'locallylinearembedding696', 'locallylinearembedding697',
#        'locallylinearembedding698', 'locallylinearembedding699',
#        'locallylinearembedding700', 'locallylinearembedding701',
#        'locallylinearembedding702', 'locallylinearembedding703',
#        'locallylinearembedding704', 'locallylinearembedding705',
#        'locallylinearembedding706', 'locallylinearembedding707',
#        'locallylinearembedding708', 'locallylinearembedding709',
#        'locallylinearembedding710', 'locallylinearembedding711',
#        'locallylinearembedding712', 'locallylinearembedding713',
#        'locallylinearembedding714', 'locallylinearembedding715',
#        'locallylinearembedding716', 'locallylinearembedding717',
#        'locallylinearembedding718', 'locallylinearembedding719',
#        'locallylinearembedding720', 'locallylinearembedding721',
#        'locallylinearembedding722', 'locallylinearembedding723',
#        'locallylinearembedding724', 'locallylinearembedding725',
#        'locallylinearembedding726', 'locallylinearembedding727',
#        'locallylinearembedding728', 'locallylinearembedding729',
#        'locallylinearembedding730', 'locallylinearembedding731',
#        'locallylinearembedding732', 'locallylinearembedding733',
#        'locallylinearembedding734', 'locallylinearembedding735',
#        'locallylinearembedding736', 'locallylinearembedding737',
#        'locallylinearembedding738', 'locallylinearembedding739',
#        'locallylinearembedding740', 'locallylinearembedding741',
#        'locallylinearembedding742', 'locallylinearembedding743',
#        'locallylinearembedding744', 'locallylinearembedding745',
#        'locallylinearembedding746', 'locallylinearembedding747',
#        'locallylinearembedding748', 'locallylinearembedding749'],
#       dtype=object)

# %%
explainer = shap.LinearExplainer(
    classification_pipeline.named_steps["classifier"],
    classification_pipeline[:-1].transform(X_train),
    feature_names=transformed_feature_names,
)

# %%
explanations = explainer(classification_pipeline[:-1].transform(X_test))

# %%
shap.plots.bar(explanations)

# %%
shap.plots.waterfall(explanations[0], max_display=6)

# %%
def model_predict(data_asarray):
    data_asframe = pd.DataFrame(data_asarray, columns=feature_names)
    return classification_pipeline.predict(data_asframe)


explainer = shap.KernelExplainer(
    model_predict,
    shap.kmeans(X_train.sample(100, random_state=RANDOM_STATE), 10),
    feature_names=feature_names,
)

# %%
explanations = explainer(X_test.iloc[0])

# %%
def model_transform(data_asarray):
    data_asframe = pd.DataFrame(data_asarray, columns=feature_names)
    return classification_pipeline[:-1].transform(data_asframe)
explainer = shap.KernelExplainer(
    model_transform,
    shap.kmeans(X_train.sample(100, random_state=RANDOM_STATE), 10),
    feature_names=feature_names,
)

# %%
shap_values = explainer.shap_values(X_test.iloc[0])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 shap_values = explainer.shap_values(X_test.iloc[0])
#
# File /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/env/jt_methylation_project/lib/python3.11/site-packages/shap/explainers/_kernel.py:256, in KernelExplainer.shap_values(self, X, **kwargs)
#     254 if self.keep_index:
#     255     data = convert_to_instance_with_index(data, column_name, index_name, index_value)
# --> 256 explanation = self.explain(data, **kwargs)
#     258 # vector-output
#     259 s = explanation.shape
#
# File /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/env/jt_methylation_project/lib/python3.11/site-packages/shap/explainers/_kernel.py:362, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     359         self.nsamples = self.max_samples
#     361 # reserve space for some of our computations
# --> 362 self.allocate()
#     364 # weight the different subset sizes
#     365 num_subset_sizes = int(np.ceil((self.M - 1) / 2.0))
#
# File /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/env/jt_methylation_project/lib/python3.11/site-packages/shap/explainers/_kernel.py:567, in KernelExplainer.allocate(self)
#     565         self.synth_data = scipy.sparse.csr_matrix((new_data, new_indices, new_indptr), shape=shape).tolil()
#     566 else:
# --> 567     self.synth_data = np.tile(self.data.data, (self.nsamples, 1))
#     569 self.maskMatrix = np.zeros((self.nsamples, self.M))
#     570 self.kernelWeights = np.zeros(self.nsamples)
#
# File <__array_function__ internals>:180, in tile(*args, **kwargs)
#
# File /uufs/chpc.utah.edu/common/home/clementm-group1/conda/mambaforge/env/jt_methylation_project/lib/python3.11/site-packages/numpy/lib/shape_base.py:1278, in tile(A, reps)
#    1276     for dim_in, nrep in zip(c.shape, tup):
#    1277         if nrep != 1:
# -> 1278             c = c.reshape(-1, n).repeat(nrep, 0)
#    1279         n //= dim_in
#    1280 return c.reshape(shape_out)
#
# MemoryError: Unable to allocate 8.30 TiB for an array with shape (478616, 2382840) and data type float64

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    classification_pipeline, X_test, y_test, n_repeats=5, random_state=RANDOM_STATE, n_jobs=20
)

# Map importance scores to original feature names
feature_importances = dict(zip(feature_names, result.importances_mean))
