# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import glob

# %%
# download data from urls and put in ../../data/raw_data then uncompress the .tar.gz files

urls = [
    "https://cbioportal-datahub.s3.amazonaws.com/brca_tcga_pan_can_atlas_2018.tar.gz",
    "https://cbioportal-datahub.s3.amazonaws.com/hnsc_tcga_pan_can_atlas_2018.tar.gz",
    "https://cbioportal-datahub.s3.amazonaws.com/prad_tcga_pan_can_atlas_2018.tar.gz",
    "https://cbioportal-datahub.s3.amazonaws.com/thca_tcga_pan_can_atlas_2018.tar.gz",
]

for url in urls:
    # !wget -P ../../data/raw_data $url
    # !tar -xvzf ../../data/raw_data/$(basename $url) -C ../../data/raw_data
# Out:
# --2024-11-20 20:28:31--  https://cbioportal-datahub.s3.amazonaws.com/brca_tcga_pan_can_atlas_2018.tar.gz
# Resolving cbioportal-datahub.s3.amazonaws.com (cbioportal-datahub.s3.amazonaws.com)... 3.5.29.254, 16.15.217.244, 52.216.213.201, ...
# Connecting to cbioportal-datahub.s3.amazonaws.com (cbioportal-datahub.s3.amazonaws.com)|3.5.29.254|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 491658872 (469M) [application/x-tar]
# Saving to: ‘../../data/raw_data/brca_tcga_pan_can_atlas_2018.tar.gz’
#
# brca_tcga_pan_can_a 100%[===================>] 468.88M  12.7MB/s    in 26s
#
# 2024-11-20 20:28:58 (18.1 MB/s) - ‘../../data/raw_data/brca_tcga_pan_can_atlas_2018.tar.gz’ saved [491658872/491658872]
#
# brca_tcga_pan_can_atlas_2018/
# brca_tcga_pan_can_atlas_2018/meta_resource_definition.txt
# brca_tcga_pan_can_atlas_2018/meta_mrna_seq_v2_rsem_zscores_ref_normal_samples.txt
# brca_tcga_pan_can_atlas_2018/data_log2_cna.txt
# ...

# %%
all_files = glob.glob("../../data/raw_data/*/data_clinical_patient.txt")

df_clinical_patient = pd.concat((pd.read_csv(f, sep='\t', skiprows=4) for f in all_files), ignore_index=True)

df_clinical_patient
# Out:
#         PATIENT_ID    SUBTYPE CANCER_TYPE_ACRONYM  \
# 0     TCGA-2A-A8VL       PRAD                PRAD
# 1     TCGA-2A-A8VO       PRAD                PRAD
# 2     TCGA-2A-A8VT       PRAD                PRAD
# 3     TCGA-2A-A8VV       PRAD                PRAD
# 4     TCGA-2A-A8VX       PRAD                PRAD
# ...            ...        ...                 ...
# 2595  TCGA-UF-A7JT  HNSC_HPV-                HNSC
# 2596  TCGA-UF-A7JV  HNSC_HPV-                HNSC
# 2597  TCGA-UP-A6WW  HNSC_HPV+                HNSC
# 2598  TCGA-WA-A7GZ  HNSC_HPV-                HNSC
# 2599  TCGA-WA-A7H4  HNSC_HPV-                HNSC
#
#                           OTHER_PATIENT_ID   AGE     SEX  \
# 0     49197847-CC83-4CE1-8397-D09CEA4C4928  51.0    Male
# 1     91C0D161-2B59-4B7A-8C19-6D26DEA31849  57.0    Male
# 2     931B549F-B9F2-4E8D-83ED-FF663671883C  47.0    Male
# 3     75A7AFB5-66D5-47E3-8A8A-3E3A1E749A96  52.0    Male
# 4     942F1788-D977-4AC0-A177-659F9D4CD077  70.0    Male
# ...

# %%
df_clinical_patient.CANCER_TYPE_ACRONYM.value_counts()
# Out:
# CANCER_TYPE_ACRONYM
# BRCA    1084
# HNSC     523
# THCA     499
# PRAD     494
# Name: count, dtype: int64

# %%
df_clinical_patient.SUBTYPE.value_counts()
# Out:
# SUBTYPE
# BRCA_LumA      499
# THCA           480
# PRAD           479
# HNSC_HPV-      415
# BRCA_LumB      197
# BRCA_Basal     171
# BRCA_Her2       78
# HNSC_HPV+       72
# BRCA_Normal     36
# Name: count, dtype: int64

# %%
df_clinical_patient.to_csv('../../data/clinical/clinical_patient.tsv', sep='\t', index=False)

# %%
all_files = glob.glob("../../data/raw_data/*/data_methylation_hm27_hm450_merged.txt")

meth_dfs = (pd.read_csv(f, sep="\t") for f in all_files)
meth_dfs = list(meth_dfs)

# %%
all_files
# Out:
# ['../../data/raw_data/prad_tcga_pan_can_atlas_2018/data_methylation_hm27_hm450_merged.txt',
#  '../../data/raw_data/thca_tcga_pan_can_atlas_2018/data_methylation_hm27_hm450_merged.txt',
#  '../../data/raw_data/brca_tcga_pan_can_atlas_2018/data_methylation_hm27_hm450_merged.txt',
#  '../../data/raw_data/hnsc_tcga_pan_can_atlas_2018/data_methylation_hm27_hm450_merged.txt']

# %%
meth_dfs = list(meth_dfs) 
meth_data_df = meth_dfs[0][["ENTITY_STABLE_ID", "NAME", "DESCRIPTION", "TRANSCRIPT_ID"]]

for df in meth_dfs:
    meth_data_df = pd.merge(meth_data_df, df, on=["ENTITY_STABLE_ID", "NAME", "DESCRIPTION", "TRANSCRIPT_ID"], how="outer")

meth_data_df
# Out:
#       ENTITY_STABLE_ID            NAME    DESCRIPTION  \
# 0           cg00000292          ATP2A1        1stExon
# 1           cg00003994           MEOX2        1stExon
# 2           cg00005847           HOXD3          5'UTR
# 3           cg00007981           PANX1        1stExon
# 4           cg00008493  KIAA1409;COX8C     Body;5'UTR
# ...                ...             ...            ...
# 22596       cg27657283  LEPRE1;C1orf50   Body;TSS1500
# 22597       cg27661264            GNAS  TSS1500;3'UTR
# 22598       cg27662379            RPN1         TSS200
# 22599       cg27662877           CYB5A        TSS1500
# 22600       cg27665659           AP1S1         TSS200
#
#                           TRANSCRIPT_ID  TCGA-2A-A8VL-01  TCGA-2A-A8VO-01  \
# 0                   NM_173201;NM_004320         0.743283         0.630143
# 1                             NM_005924         0.072272         0.133472
# 2                             NM_006898         0.615289         0.566151
# ...

# %%
meth_data_df.to_csv('../../data/methylation/hm27_hm450_merge_meth_data.tsv', sep='\t', index=False)

# %%
SAMPLES_FILE = "/uufs/chpc.utah.edu/common/home/u0914269/clement/projects/20230828_tcga_methylation/data/old_data/runAll.sh.samples"
METH_REF_FILE = "/uufs/chpc.utah.edu/common/home/u0914269/clement/projects/20230828_tcga_methylation/data/old_data/parse450K.pl.order.lookup"

# %%
sample_info = pd.read_csv(SAMPLES_FILE, sep="\t")

# %%
sample_info = sample_info[sample_info.project_id.isin(["TCGA-BRCA", "TCGA-HNSC", "TCGA-PRAD", "TCGA-THCA"])]

# %%
supplemental_normal_samples = sample_info[
    sample_info.sample_type == "Solid Tissue Normal"
]
supplemental_normal_samples = supplemental_normal_samples[
    ~supplemental_normal_samples['sample'].isin(meth_data_df.columns)
]
supplemental_normal_samples
# Out:
#                 sample                                         expression  \
# 617   TCGA-EL-A3T2-11A  04bbfd91-0b04-4659-a32b-ee3afbc1f30e.rna_seq.a...
# 619   TCGA-EL-A3ZK-11A  a95698a9-7195-4a71-b09b-eb22cd9bc110.rna_seq.a...
# 624   TCGA-ET-A2N5-11B  4b3cd398-e205-4fe3-9c42-4827b390372d.rna_seq.a...
# 625   TCGA-EL-A3N2-11A  17d7a5b4-345f-48ec-9dda-0ff870e7698b.rna_seq.a...
# 637   TCGA-BJ-A28X-11A  7ac8fff8-0078-4e00-ac25-3145f416311e.rna_seq.a...
# ...                ...                                                ...
# 9680  TCGA-E9-A1RD-11A  eba8b055-6de2-48e7-bed8-40de705ad1d1.rna_seq.a...
# 9686  TCGA-BH-A1FR-11B  cc502455-f72f-491d-9486-a344e169dcfc.rna_seq.a...
# 9687  TCGA-E9-A1RC-11A  3daeb643-20a6-4273-b1fc-eed2a3bb5a18.rna_seq.a...
# 9696  TCGA-BH-A1F8-11B  bf3ea4a0-bcd6-4e9d-acbb-3416f6ce53b7.rna_seq.a...
# 9711  TCGA-BH-A0B3-11B  d920c232-82ae-48f9-98d1-b94bf4a45d8d.rna_seq.a...
#
#                                         expression_file  \
# ...

# %%
len(supplemental_normal_samples[supplemental_normal_samples["project_descriptor"] == "Breast invasive carcinoma"])
# Out:
# 84

# %%
supplemental_normal_samples.to_csv('../../data/methylation/normals/normal_samples_info.tsv', sep='\t', index=False)

# %%
import numpy as np


def get_methylation_df_hm450k(samples_file=None, meth_ref_file=None, samples_info=None):
    if samples_info is None:
        sample_info = pd.read_csv(samples_file, sep="\t")
    else:
        sample_info = samples_info
    meth_ref = pd.read_csv(meth_ref_file, sep="\t")

    meth_vals = {}
    for sample in sample_info["sample"]:
        meth_file = sample_info[sample_info["sample"] == sample][
            "methylation_file"
        ].values[0]
        meth = np.load(meth_file).astype(float)
        meth[meth == 255] = np.nan

        meth_vals[sample] = meth

    methylation_values_df = pd.DataFrame(meth_vals)

    methylation_df = pd.concat(
        [
            meth_ref.reset_index(drop=True),
            methylation_values_df.reset_index(drop=True),
        ],
        axis=1,
    )

    methylation_df["start"] = methylation_df["CpG_beg"]
    methylation_df["end"] = methylation_df["CpG_end"]
    methylation_df["chrom"] = methylation_df["CpG_chrm"]

    # Drop unused columns and convert relevant columns to integers with proper error handling.
    columns_to_drop = ["CpG_beg", "CpG_chrm"] + list(
        set(methylation_df.columns)
        - set(meth_vals.keys())
        - {"CpG_ beg", "CpG_chrm", "start", "end", "chrom"}
    )
    methylation_df = methylation_df.drop(columns=columns_to_drop)

    methylation_df = methylation_df[["chrom", "start", "end"] + list(meth_vals.keys())]

    return methylation_df

# %%
normal_meth_data = get_methylation_df_hm450k(meth_ref_file=METH_REF_FILE, samples_info=supplemental_normal_samples)

# %%
meth_ref = pd.read_csv(METH_REF_FILE, sep="\t")

# %%
meth_ref = pd.read_csv(METH_REF_FILE, sep="\t")

# %%
meth_ref
# Out:
#                key CpG_chrm  CpG_beg  CpG_end probe_strand     probeID  \
# 0       cg13869341     chr1  15864.0  15866.0            -  cg13869341
# 1       cg14008030     chr1  18826.0  18828.0            -  cg14008030
# 2       cg12045430     chr1  29406.0  29408.0            -  cg12045430
# 3       cg20826792     chr1  29424.0  29426.0            -  cg20826792
# 4       cg00381604     chr1  29434.0  29436.0            -  cg00381604
# ...            ...      ...      ...      ...          ...         ...
# 485572  cg24238852      NaN      NaN      NaN            *  cg24238852
# 485573  cg15254640      NaN      NaN      NaN            *  cg15254640
# 485574  cg24336839      NaN      NaN      NaN            *  cg24336839
# 485575  cg11478607      NaN      NaN      NaN            *  cg11478607
# 485576  cg08417382      NaN      NaN      NaN            *  cg08417382
#
#                            genesUniq  \
# 0                             WASH7P
# ...

# %%
normal_meth_data["key"] = meth_ref["key"]
normal_meth_data.drop(columns=["chrom", "start", "end"], inplace=True)

# %%
normal_meth_data.to_csv(
    "../../data/methylation/normals/normal_samples_450K.tsv", sep="\t", index=False
)

# %%
len(meth_data_df['ENTITY_STABLE_ID'])
# Out:
# 22601

# %%
len(meth_ref["key"])
# Out:
# 485577

# %%
common_keys = set(meth_ref["key"]).intersection(set(meth_data_df['ENTITY_STABLE_ID']))
common_keys = list(common_keys)
len(common_keys)
# Out:
# 22601

# %%
normal_hm27_hm450_meth_data = normal_meth_data[meth_ref["key"].isin(common_keys)]
normal_hm27_hm450_meth_data.to_csv(
    "../../data/methylation/normals/normal_samples_hm27.tsv", sep="\t", index=False
)
